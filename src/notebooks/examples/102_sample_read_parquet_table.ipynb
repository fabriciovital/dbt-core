# %% [markdown]
# ## Sample read Delta table on Minio

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from dotenv import load_dotenv
import os

# %%
load_dotenv()

HOST_ADDRESS = os.getenv("HOST_ADDRESS")
MINIO_ACCESS_KEY = os.getenv("MINIO_ACCESS_KEY")
MINIO_SECRET_KEY = os.getenv("MINIO_SECRET_KEY")

conf = SparkConf()

conf.setAppName("Sample read Delta table")
conf.set("spark.hadoop.fs.s3a.endpoint", f"http://{HOST_ADDRESS}:9000")
conf.set("spark.hadoop.fs.s3a.access.key", MINIO_ACCESS_KEY)
conf.set("spark.hadoop.fs.s3a.secret.key", MINIO_SECRET_KEY)
conf.set("spark.hadoop.fs.s3a.path.style.access", True)
conf.set("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
conf.set('spark.hadoop.fs.s3a.aws.credentials.provider', 'org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider')
conf.set("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
conf.set("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") 
conf.set("hive.metastore.uris", "thrift://metastore:9083")

spark = SparkSession.builder.config(conf=conf).enableHiveSupport().getOrCreate()

# %%
# Ler os arquivos Parquet com limite
df_parquet = spark.read.format("parquet").load('s3a://landing/isp_performance/landing_ordem_servico_aberto') \
    .filter("id IS NOT NULL") \
    .limit(100)

df_parquet.show()
# Out:
# +----------------+-------------------+-------------------+-------------------+-------------------+-------------+-------+-------------------+------+----+--------+-----------+---------+-------------------+-------------------+--------+------+---------+---------+-----+--------+---------+----------+--------------------+------------+--------------------+--------------------+------------+--------------+-----------+-------------------+--------------------+-------------------+--------------------+--------+-------------------+-------------------+-------------------+-------------------+------------+------------------+----------+-------------------+----+---------------+------------+-----------+-------+-----------------+-------------------+-------------+--------+--------------+------------------------+-----------------------+-------------------+-------------------+--------------+-------------------+--------------------+---------+
# |mensagemResposta|    dataHoraAnalise|dataHoraEncaminhado|   dataHoraAssumido|   dataHoraExecucao|idContratoKit|preview|    dataAgendaFinal|    id|tipo|idFilial|idWflTarefa|statusSla|       dataAbertura|melhorHorarioAgenda|liberado|status|idCliente|idAssunto|setor|idCidade|idTecnico|prioridade|            mensagem|   protocolo|            endereco|         complemento|idCondominio|         bloco|apartamento|           latitude|              bairro|          longitude|          referencia|impresso|         dataInicio|         dataAgenda|          dataFinal|     dataFechamento|idWflParamOs|valorTotalComissao|valorTotal|valorOutrasDespesas| idx|idSuDiagnostico|geraComissao|idEstrutura|idLogin|valorUnitComissao|    dataPrazoLimite|dataReservada|idTicket|origemEndereco|justificativaSlaAtrasado|origemEnderecoEstrutura|      dataReagendar|      dataPrevFinal|origemCadastro|  ultimaAtualizacao|         last_update|month_key|
# +----------------+-------------------+-------------------+-------------------+-------------------+-------------+-------+-------------------+------+----+--------+-----------+---------+-------------------+-------------------+--------+------+---------+---------+-----+--------+---------+----------+--------------------+------------+--------------------+--------------------+------------+--------------+-----------+-------------------+--------------------+-------------------+--------------------+--------+-------------------+-------------------+-------------------+-------------------+------------+------------------+----------+-------------------+----+---------------+------------+-----------+-------+-----------------+-------------------+-------------+--------+--------------+------------------------+-----------------------+-------------------+-------------------+--------------+-------------------+--------------------+---------+
# |            null|               null|               null|               null|               null|        37939|   null|               null|614360|   C|      28|        119|     null|2024-10-09 08:48:42|                  Q|       1|     A|    31092|      410|    4|    5209|        0|         A|Processo: Process...|202410211485|MT Colniza 78335-...| AOS FUNDO DA LI GAS|           0|          null|       null|  -9.45959634451431|        CIDADE ALTA |-59.214173055819685|                null|       N|               null|               null|               null|               null|          51|              0.00|      null|               null|null|           null|           S|       null|  34429|             0.00|2024-10-09 14:48:42|   0000-00-00|  192307|             C|                    null|                      E|               null|               null|             P|2024-10-09 08:48:42|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        49676|   null|               null|614361|   C|       4|        170|     null|2024-10-09 08:49:16|                  M|       1|     A|    39376|      449|    9|      23|        0|         A|Processo: Process...|202410211486|RO São Miguel do ...|CASA DE MADEIRA S...|           0|          null|       null|               null|        NOVO ORIENTE|               null|                null|       N|               null|               null|               null|               null|          87|              0.00|      null|               null|null|           null|           S|       null|  43799|             0.00|               null|   2024-10-09|  192238|             L|                    null|                      E|               null|               null|             P|2024-10-09 08:49:16|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        50687|   null|               null|614364|   C|       1|        370|     null|2024-10-09 08:49:37|                  M|       1|     A|    40120|      494|    9|      16|        0|         N|Processo: Process...|202410211489|RO Pimenta Bueno ...|                null|           0|          null|       null|               null|           VILA NOVA|               null|                null|       N|               null|               null|               null|               null|         124|              0.00|      null|               null|null|           null|           S|       null|  44706|             0.00|               null|   2024-10-09|  192377|             L|                    null|                      E|               null|               null|             P|2024-10-09 08:49:37|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        50652|   null|2024-10-30 08:00:00|614366|   C|      30|        372|     null|2024-10-09 08:50:06|                  M|       1|    AG|    40094|      496|    4|    5235|      511|         N|Processo: Process...|202410211491|MT Juína 78320-00...|                   W|           0|          null|       null|-11.425099778883705|           MODULO 06| -58.79155485833055|                null|       N|               null|2024-10-17 14:16:00|               null|               null|         126|              0.00|      null|               null|null|           null|           S|       null|  44679|             0.00|               null|   2024-10-09|  192191|             L|                    null|                      E|               null|               null|             P|2024-10-17 14:15:53|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        50686|   null|2024-10-29 08:30:32|614368|   C|       1|        372|     null|2024-10-09 08:50:28|                  T|       1|    AG|    40104|      496|    4|      16|      524|         N|Processo: Process...|202410211493|RO Pimenta Bueno ...|                null|           0|          null|       null|               null|JARDIM DAS OLIVEIRAS|               null|                null|       N|               null|2024-10-29 08:01:54|               null|               null|         126|              0.00|      null|               null|null|           null|           S|       null|  44704|             0.00|               null|   2024-10-08|  192372|             L|                    null|                      E|               null|               null|             P|2024-10-09 09:30:04|2024-10-21 03:29:...|   202410|
# |            null|0000-00-00 00:00:00|0000-00-00 00:00:00|0000-00-00 00:00:00|0000-00-00 00:00:00
2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        30005|   null|               null|614413|   C|      15|        382|     null|2024-10-09 09:15:55|                  Q|       1|     A|    25862|      435|    2|      51|        0|         A|Processo: Process...|202410211544|RO Vale do Anari ...|            OFICINA |           0|          null|       null|         -9.8497725|              CENTRO|         -62.174512|                null|       N|               null|               null|               null|               null|          68|              0.00|      null|               null|null|           null|           S|       null|  28079|             0.00|               null|   0000-00-00|  192477|             L|                    null|                      E|               null|               null|             P|2024-10-09 09:15:55|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        50645|   null|               null|614419|   C|      14|        382|     null|2024-10-09 09:20:27|                  Q|       1|     A|    40093|      435|    2|      13|        0|         A|Processo: Process...|202410211551|RO Machadinho D'O...|                null|           0|          null|       null|               null|               UNIAO|               null|ULTIMA CASA DA RU...|       N|               null|               null|               null|               null|          68|              0.00|      null|               null|null|           null|           S|       null|  44672|             0.00|               null|   0000-00-00|  192478|             L|                    null|                      E|               null|               null|             P|2024-10-09 09:20:27|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        50645|   null|2024-11-05 08:30:48|614421|   C|      14|        372|     null|2024-10-09 09:22:14|                  M|       1|    AG|    40093|      496|    4|      13|      318|         N|Processo: Process...|202410211554|RO Machadinho D'O...|                null|           0|          null|       null|               null|               UNIAO|               null|ULTIMA CASA DA RU...|       N|               null|2024-11-05 08:00:41|               null|               null|         126|              0.00|      null|               null|null|           null|           S|       null|  44672|             0.00|               null|   2024-10-08|  192162|             C|                    null|                      E|               null|               null|             P|2024-10-09 09:22:45|2024-10-21 03:29:...|   202410|
# |            null|               null|               null|               null|               null|        43980|   null|0000-00-00 00:00:00|614423|   C|       3|        120|     null|2024-10-09 09:22:16|                  Q|       1|     A|    35372|      354|    9|       1|        0|         N|Processo: Process...|202410211556|RO Alta Floresta ...|                null|           0|          null|       null|-11.935454975744591|             REDONDO| -62.00060145184034|AO LADO DA SECRET...|       N|0000-00-00 00:00:00|0000-00-00 00:00:00|               null|0000-00-00 00:00:00|          47|              0.00|      0.00|               0.00|   0|              0|           S|          0|  39244|             0.00|2024-10-09 15:22:16|   0000-00-00|  192480|             L|                    null|                      E|0000-00-00 00:00:00|0000-00-00 00:00:00|             P|2024-10-09 09:28:34|2024-10-21 03:29:...|   202410|
# +----------------+-------------------+-------------------+-------------------+-------------------+-------------+-------+-------------------+------+----+--------+-----------+---------+-------------------+-------------------+--------+------+---------+---------+-----+--------+---------+----------+--------------------+------------+--------------------+--------------------+------------+--------------+-----------+-------------------+--------------------+-------------------+--------------------+--------+-------------------+-------------------+-------------------+-------------------+------------+------------------+----------+-------------------+----+---------------+------------+-----------+-------+-----------------+-------------------+-------------+--------+--------------+------------------------+-----------------------+-------------------+-------------------+--------------+-------------------+--------------------+---------+
# only showing top 20 rows
